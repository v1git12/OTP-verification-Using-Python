# %% [markdown]
# # OTP verification Using Pywhatkit

# %%
#importing Essential Libraries
# !pip install pywhatkit
import random,math,os
import pywhatkit as kit

#Random OTP Generator
digits="0123456789"
OTP=""
for i in range(6):
    OTP+=digits[math.floor(random.random()*10)]
otp = OTP + " is your OTP to verify your identity"
msg= otp

#Getting email id from user
emailid = input("Enter your email: ")

#Send the message from Company's/ personal email-id (You can try Both)
kit.send_mail("Your Email","Your Password","New Email from pywhatkit Auomation by Your_Nmae",f"{msg}",f"{emailid}")
print("An OTP is sent to Your email please check your inbox")
a = input("Enter Your OTP >>: ")
if a == OTP:
    print("Your OTP Successfully Verified !!!")
    kit.send_mail("Your Email","Your Password","Email Verification","Your Email is Succesfully verified!!" ,f"{emailid}")
else:
    print("Incorrect OTP!!! \nPlease Check your OTP and try again")
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting pywhatkit
#   Downloading pywhatkit-4.8-py3-none-any.whl (11 kB)
# Collecting pyautogui
#   Downloading PyAutoGUI-0.9.52.tar.gz (55 kB)
#      |████████████████████████████████| 55 kB 5.5 MB/s  eta 0:00:01
# Requirement already satisfied: Pillow in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pywhatkit) (7.2.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pywhatkit) (2.24.0)
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
# Collecting pymsgbox
#   Downloading PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting PyTweening>=1.0.1
#   Downloading PyTweening-1.0.3.zip (15 kB)
# Collecting pyscreeze>=0.1.21
#   Downloading PyScreeze-0.1.27.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting pygetwindow>=0.0.5
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
# Collecting mouseinfo
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
# Collecting python3-Xlib
#   Downloading python3-xlib-0.15.tar.gz (132 kB)
#      |████████████████████████████████| 132 kB 30.4 MB/s eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->pywhatkit) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->pywhatkit) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->pywhatkit) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->pywhatkit) (1.25.9)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from wikipedia->pywhatkit) (4.9.1)
# Collecting pyrect
#   Downloading PyRect-0.1.4.tar.gz (15 kB)
# Collecting pyperclip
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from beautifulsoup4->wikipedia->pywhatkit) (2.0.1)
# Building wheels for collected packages: pyautogui, wikipedia, pymsgbox, PyTweening, pyscreeze, pygetwindow, mouseinfo, python3-Xlib, pyrect, pyperclip
#   Building wheel for pyautogui (setup.py) ... done
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.52-py3-none-any.whl size=35193 sha256=3754cdce082a9a9778cc037322cefd87c08106df442d4aa19bd288a36347082b
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/f6/f6/b0/15c9d2d3aff00cece56b54184f638bb6342212e1977482f8aa
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11685 sha256=0333d5a41e99b85292db031e586f49d1dab04a01f8917da809e3e1c626d50b51
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/15/93/6d/5b2c68b8a64c7a7a04947b4ed6d89fb557dcc6bc27d1d7f3ba
#   Building wheel for pymsgbox (PEP 517) ... done
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7420 sha256=06894c33913da7258ced1d7a71eac820abf3e5dabd9abbef503b79ae0df652b8
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/39/eb/0e/1587e06da34adf675ad26a113da25df542991f5095303374ef
#   Building wheel for PyTweening (setup.py) ... done
#   Created wheel for PyTweening: filename=PyTweening-1.0.3-py3-none-any.whl size=3815 sha256=b34923eb592ce94cf43e85c7116e65ec8d4c62b87b242ba3b0aa99f55c464cb2
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/1c/ca/56/5da436934a2b244752a7ebc864407729a098271a531a29493c
#   Building wheel for pyscreeze (PEP 517) ... done
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.27-py3-none-any.whl size=12891 sha256=ba13d779cdc41301bb5f176e7e2cbee9fc80b7453c0c1486dbdbc33cc8e68f74
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/e7/cf/e4/6a16ce50f4213c83255fb057549e804a03ffa1ace412130e45
#   Building wheel for pygetwindow (setup.py) ... done
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11082 sha256=c91a310500416e36c233b5c9a1821239fdfe204edd6b3f0a0429b3efe62dbcb1
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/91/7e/35/62d9062a06cfc46fea39e26860253da36f258b3f3fd96c91c3
#   Building wheel for mouseinfo (setup.py) ... done
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10906 sha256=b0f9a1419c402bd3dec5f1342989d7757473ef2724230265c52f291ee8e0392c
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/43/9a/7f/373736bf37b94b358be41fb2f317a0f9940a1dcb7a733e1707
#   Building wheel for python3-Xlib (setup.py) ... done
#   Created wheel for python3-Xlib: filename=python3_xlib-0.15-py3-none-any.whl size=109517 sha256=b8fda5ae95415759875bf2234f6239048ded8c3687306e7c71dbc9c63809a16e
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/67/6f/f2/18f51230840318e784c45e1392a0e174777e499251e42ddf86
#   Building wheel for pyrect (setup.py) ... done
#   Created wheel for pyrect: filename=PyRect-0.1.4-py2.py3-none-any.whl size=9547 sha256=ab929171483c5951ea39e078942eecfe58e95d9534731ee774465c6014c8528d
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/97/5f/8e/6f26a5b00d46679ee2391a3542334274ce8bdaf7c6b0f3504c
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11107 sha256=da1500719f6bb788c4c79140bb6c38b701833dc5ab531e04014a5261d01ccc13
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyautogui wikipedia pymsgbox PyTweening pyscreeze pygetwindow mouseinfo python3-Xlib pyrect pyperclip
# Installing collected packages: pymsgbox, PyTweening, pyscreeze, pyrect, pygetwindow, pyperclip, python3-Xlib, mouseinfo, pyautogui, wikipedia, pywhatkit
# Successfully installed PyTweening-1.0.3 mouseinfo-0.1.3 pyautogui-0.9.52 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.1.4 pyscreeze-0.1.27 python3-Xlib-0.15 pywhatkit-4.8 wikipedia-1.4.0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-a91e601bcf5c> in <module>
#       2 get_ipython().system('pip install pywhatkit')
#       3 import random,math,os
# ----> 4 import pywhatkit as kit
#       5
#       6 #Random OTP Generator
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pywhatkit/__init__.py in <module>
#       4 from pywhatkit.chr_to_handwriting import text_to_handwriting
#       5 import pywhatkit.help
# ----> 6 from pywhatkit.main import open_web, print_sleep_time, check_window, sendwhatmsg, sendwhatmsg_to_group, info, playonyt, search, take_screenshot, close_tab, sendwhatmsg_instantly
#       7 from pywhatkit.sc import shutdown, cancel_shutdown
#       8 from pywhatkit.wwd import tutorial_english, tutorial_hindi, developer_contact, join_discord
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pywhatkit/main.py in <module>
#       1 import time
#       2 import webbrowser as web
# ----> 3 import pyautogui as pg
#       4 import wikipedia
#       5 import requests
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pyautogui/__init__.py in <module>
#     239
#     240 try:
# --> 241     import mouseinfo
#     242
#     243     def mouseInfo():
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/mouseinfo/__init__.py in <module>
#     221             raise
#     222
# --> 223     _display = Display(os.environ['DISPLAY'])
#     224
#     225     def _linuxPosition():
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/os.py in __getitem__(self, key)
#     679         except KeyError:
#     680             # raise KeyError with the original key value
# --> 681             raise KeyError(key) from None
#     682         return self.decodevalue(value)
#     683
#
# KeyError: 'DISPLAY'
